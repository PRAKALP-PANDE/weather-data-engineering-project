# %%
spark.range(5).show()
# Out:
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+

# %%
dbutils.fs.ls("/")
# Out:
# [FileInfo(path='dbfs:/Volumes/', name='Volumes/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/Workspace/', name='Workspace/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0)]

# %%
display(dbutils.fs.ls("/Volumes"))
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-8925454708017141>, line 1
# ----> 1 display(dbutils.fs.ls("/Volumes"))
#
# File /databricks/python_shell/lib/dbruntime/remotefshandler/RemoteFsHandler.py:56, in prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#      52     pass
#      54 error_exception = ExecutionError(str(e))
# ---> 56 raise patch_exception_with_error_details(
#      57     error_exception,
#      58     DriverErrorCode.REMOTE_FS_HANDLER_EXECUTION_ERROR  # type: ignore[attr-defined]
#      59 ) from None
#
# ExecutionError: (com.databricks.backend.daemon.data.client.DbfsSparkException) [INVALID_VOLUME_ACCESS] Entry must be a full volume path. Path '/Volumes' is incomplete. Expected format: /Volumes/{catalog}/{schema}/{volume}.
#  SQLSTATE: 42KDO
#
# JVM stacktrace:
# ...

# %%
display(
    dbutils.fs.ls(
        "/Volumes/workspace/default/weather_raw"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.json(
    "/Volumes/workspace/default/weather_raw"
)

display(df)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8925454708017143>, line 5
#       1 df = spark.read.json(
#       2     "/Volumes/workspace/default/weather_raw"
#       3 )
# ----> 5 display(df)
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:100, in Display.display_connect_table(self, df, **kwargs)
#      97     self.cf_helper.display_streaming_dataframe(df, config, self.streaming_listener,
#      98                                                **kwargs)
#      99 else:
# ...

# %%
display(
    dbutils.fs.ls(
        "/Volumes/workspace/default/weather_raw"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(
    spark.read.text(
        "/Volumes/workspace/default/weather_raw"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.json(
    "dbfs:/Volumes/workspace/default/weather_raw/20260613_153731.json"
)

display(df)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8925454708017146>, line 5
#       1 df = spark.read.json(
#       2     "dbfs:/Volumes/workspace/default/weather_raw/20260613_153731.json"
#       3 )
# ----> 5 display(df)
#
# File /databricks/python_shell/lib/dbruntime/display.py:136, in Display.display(self, input, *args, **kwargs)
#     134     pass
#     135 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 136     self.display_connect_table(input, **kwargs)
#     137 elif isinstance(input, ConnectDataFrame):
#     138     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:100, in Display.display_connect_table(self, df, **kwargs)
#      97     self.cf_helper.display_streaming_dataframe(df, config, self.streaming_listener,
#      98                                                **kwargs)
# ...

# %%
display(
    spark.read.text(
        "/Volumes/workspace/default/weather_raw"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = (
    spark.read
    .option("multiLine", "true")
    .json("/Volumes/workspace/default/weather_raw")
)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
